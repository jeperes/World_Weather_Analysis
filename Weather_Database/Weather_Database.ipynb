# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dd47f5523dfd1ab68616013eb64cd6d2

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chililabombwe
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | murgud
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | kirakira
# Processing Record 7 of Set 1 | sibu
# Processing Record 8 of Set 1 | flinders
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | selma
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | puttur
# Processing Record 13 of Set 1 | dicabisagan
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | faya
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | marcona
# City not found. Skipping
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | demyansk
# Processing Record 21 of Set 1 | fayaoue
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | archidona
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | saint-pierre
# Processing Record 26 of Set 1 | cabedelo
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | bairiki
# Processing Record 29 of Set 1 | tabuk
# Processing Record 30 of Set 1 | maldonado
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | hamilton
# Processing Record 33 of Set 1 | mutsamudu
# City not found. Skipping
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | bandrele
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | evensk
# Processing Record 38 of Set 1 | samusu
# City not found. Skipping
# Processing Record 39 of Set 1 | ukiah
# Processing Record 40 of Set 1 | visconde do rio branco
# Processing Record 41 of Set 1 | iqaluit
# Processing Record 42 of Set 1 | mitu
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | praia da vitoria
# Processing Record 46 of Set 1 | bahir dar
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | codrington
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | karatau
# Processing Record 2 of Set 2 | inirida
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | yar-sale
# Processing Record 6 of Set 2 | nizhneyansk
# City not found. Skipping
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | kavieng
# Processing Record 9 of Set 2 | santa maria
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | douglas
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | jesenice
# Processing Record 14 of Set 2 | mendahara
# City not found. Skipping
# Processing Record 15 of Set 2 | geraldton
# Processing Record 16 of Set 2 | canavieiras
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | kamenskoye
# City not found. Skipping
# Processing Record 20 of Set 2 | christchurch
# Processing Record 21 of Set 2 | mackay
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping
# Processing Record 24 of Set 2 | kushiro
# Processing Record 25 of Set 2 | cidreira
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping
# Processing Record 27 of Set 2 | tsihombe
# City not found. Skipping
# Processing Record 28 of Set 2 | nome
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | tulun
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | shingu
# Processing Record 33 of Set 2 | port hardy
# Processing Record 34 of Set 2 | avera
# Processing Record 35 of Set 2 | pingxiang
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping
# Processing Record 37 of Set 2 | touros
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | dhidhdhoo
# Processing Record 40 of Set 2 | merauke
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | nicoya
# Processing Record 43 of Set 2 | taoudenni
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | coquimbo
# Processing Record 46 of Set 2 | andenes
# Processing Record 47 of Set 2 | khuzhir
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | kahului
# Processing Record 50 of Set 2 | vaitupu
# City not found. Skipping
# Processing Record 1 of Set 3 | amderma
# City not found. Skipping
# Processing Record 2 of Set 3 | port-cartier
# Processing Record 3 of Set 3 | caconda
# Processing Record 4 of Set 3 | severo-kurilsk
# Processing Record 5 of Set 3 | haibowan
# City not found. Skipping
# Processing Record 6 of Set 3 | sao joaquim
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | hokitika
# Processing Record 9 of Set 3 | alice springs
# Processing Record 10 of Set 3 | caravelas
# Processing Record 11 of Set 3 | le port
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | karratha
# Processing Record 14 of Set 3 | aksarayskiy
# Processing Record 15 of Set 3 | nidzica
# Processing Record 16 of Set 3 | sungaipenuh
# Processing Record 17 of Set 3 | grand river south east
# City not found. Skipping
# Processing Record 18 of Set 3 | ketchikan
# Processing Record 19 of Set 3 | tashtyp
# Processing Record 20 of Set 3 | gotsu
# Processing Record 21 of Set 3 | albany
# Processing Record 22 of Set 3 | liberty
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | the valley
# Processing Record 25 of Set 3 | castro
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | golden
# Processing Record 28 of Set 3 | taywarah
# Processing Record 29 of Set 3 | fortuna
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | sapa
# Processing Record 33 of Set 3 | dolores
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | kawalu
# Processing Record 36 of Set 3 | puerto escondido
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | isangel
# Processing Record 39 of Set 3 | tarudant
# City not found. Skipping
# Processing Record 40 of Set 3 | ahipara
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | havre-saint-pierre
# Processing Record 43 of Set 3 | la palma
# Processing Record 44 of Set 3 | kaeo
# Processing Record 45 of Set 3 | bengkulu
# Processing Record 46 of Set 3 | kailua
# Processing Record 47 of Set 3 | bima
# Processing Record 48 of Set 3 | tulsipur
# Processing Record 49 of Set 3 | upernavik
# Processing Record 50 of Set 3 | springbok
# Processing Record 1 of Set 4 | sokolow podlaski
# Processing Record 2 of Set 4 | severodvinsk
# Processing Record 3 of Set 4 | san cristobal
# Processing Record 4 of Set 4 | dubai
# Processing Record 5 of Set 4 | college
# Processing Record 6 of Set 4 | elat
# Processing Record 7 of Set 4 | seoul
# Processing Record 8 of Set 4 | bandarbeyla
# Processing Record 9 of Set 4 | norman wells
# Processing Record 10 of Set 4 | kapaa
# Processing Record 11 of Set 4 | arrifes
# Processing Record 12 of Set 4 | longyearbyen
# Processing Record 13 of Set 4 | melioratorov
# Processing Record 14 of Set 4 | marga
# Processing Record 15 of Set 4 | zyryanka
# Processing Record 16 of Set 4 | mnogovershinnyy
# Processing Record 17 of Set 4 | naryan-mar
# Processing Record 18 of Set 4 | hofn
# Processing Record 19 of Set 4 | hasaki
# Processing Record 20 of Set 4 | luganville
# Processing Record 21 of Set 4 | huron
# Processing Record 22 of Set 4 | gimli
# Processing Record 23 of Set 4 | kununurra
# Processing Record 24 of Set 4 | chicama
# Processing Record 25 of Set 4 | katsuura
# Processing Record 26 of Set 4 | ortakoy
# Processing Record 27 of Set 4 | mantua
# Processing Record 28 of Set 4 | harstad
# Processing Record 29 of Set 4 | vardo
# Processing Record 30 of Set 4 | antofagasta
# Processing Record 31 of Set 4 | tromso
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping
# Processing Record 33 of Set 4 | businga
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | mildura
# Processing Record 36 of Set 4 | tumannyy
# City not found. Skipping
# Processing Record 37 of Set 4 | torbay
# Processing Record 38 of Set 4 | kieta
# Processing Record 39 of Set 4 | east london
# Processing Record 40 of Set 4 | sovetskiy
# Processing Record 41 of Set 4 | saldanha
# Processing Record 42 of Set 4 | umm kaddadah
# Processing Record 43 of Set 4 | tezu
# Processing Record 44 of Set 4 | ippy
# Processing Record 45 of Set 4 | barra do garcas
# Processing Record 46 of Set 4 | bambous virieux
# Processing Record 47 of Set 4 | moose factory
# Processing Record 48 of Set 4 | tual
# Processing Record 49 of Set 4 | pontes e lacerda
# Processing Record 50 of Set 4 | saleaula
# City not found. Skipping
# Processing Record 1 of Set 5 | kralendijk
# Processing Record 2 of Set 5 | cockburn town
# Processing Record 3 of Set 5 | nova lima
# Processing Record 4 of Set 5 | nagapattinam
# Processing Record 5 of Set 5 | aberdeen
# Processing Record 6 of Set 5 | boende
# Processing Record 7 of Set 5 | los llanos de aridane
# Processing Record 8 of Set 5 | port elizabeth
# Processing Record 9 of Set 5 | alekseyevsk
# Processing Record 10 of Set 5 | forest
# Processing Record 11 of Set 5 | falaleu
# City not found. Skipping
# Processing Record 12 of Set 5 | luderitz
# Processing Record 13 of Set 5 | bismarck
# Processing Record 14 of Set 5 | port augusta
# Processing Record 15 of Set 5 | benguela
# Processing Record 16 of Set 5 | noumea
# Processing Record 17 of Set 5 | san juan del sur
# Processing Record 18 of Set 5 | teguise
# Processing Record 19 of Set 5 | dunedin
# Processing Record 20 of Set 5 | monrovia
# Processing Record 21 of Set 5 | hovd
# Processing Record 22 of Set 5 | srednekolymsk
# Processing Record 23 of Set 5 | ostrovnoy
# Processing Record 24 of Set 5 | broken hill
# Processing Record 25 of Set 5 | hilo
# Processing Record 26 of Set 5 | radstadt
# Processing Record 27 of Set 5 | marsabit
# Processing Record 28 of Set 5 | bontang
# Processing Record 29 of Set 5 | caborca
# Processing Record 30 of Set 5 | mikhaylovka
# Processing Record 31 of Set 5 | kaitangata
# Processing Record 32 of Set 5 | tymovskoye
# Processing Record 33 of Set 5 | saint-francois
# Processing Record 34 of Set 5 | safaqis
# City not found. Skipping
# Processing Record 35 of Set 5 | mana
# Processing Record 36 of Set 5 | ostrovskoye
# Processing Record 37 of Set 5 | kismayo
# Processing Record 38 of Set 5 | harper
# Processing Record 39 of Set 5 | ternate
# Processing Record 40 of Set 5 | altagracia de orituco
# Processing Record 41 of Set 5 | zemio
# Processing Record 42 of Set 5 | sabang
# Processing Record 43 of Set 5 | nanortalik
# Processing Record 44 of Set 5 | cayenne
# Processing Record 45 of Set 5 | muros
# Processing Record 46 of Set 5 | sioux lookout
# Processing Record 47 of Set 5 | saint-prosper
# Processing Record 48 of Set 5 | grand gaube
# Processing Record 49 of Set 5 | halalo
# City not found. Skipping
# Processing Record 50 of Set 5 | imperatriz
# Processing Record 1 of Set 6 | barabai
# Processing Record 2 of Set 6 | nemuro
# Processing Record 3 of Set 6 | warqla
# City not found. Skipping
# Processing Record 4 of Set 6 | mount gambier
# Processing Record 5 of Set 6 | amuntai
# Processing Record 6 of Set 6 | ancud
# Processing Record 7 of Set 6 | saint-augustin
# Processing Record 8 of Set 6 | vostok
# Processing Record 9 of Set 6 | aklavik
# Processing Record 10 of Set 6 | santa eulalia del rio
# City not found. Skipping
# Processing Record 11 of Set 6 | oussouye
# Processing Record 12 of Set 6 | coahuayana
# Processing Record 13 of Set 6 | presidencia roque saenz pena
# Processing Record 14 of Set 6 | portland
# Processing Record 15 of Set 6 | okha
# Processing Record 16 of Set 6 | colares
# Processing Record 17 of Set 6 | batamshinskiy
# Processing Record 18 of Set 6 | rusape
# Processing Record 19 of Set 6 | xining
# Processing Record 20 of Set 6 | male
# Processing Record 21 of Set 6 | mujiayingzi
# Processing Record 22 of Set 6 | fairbanks
# Processing Record 23 of Set 6 | vestmannaeyjar
# Processing Record 24 of Set 6 | bilma
# Processing Record 25 of Set 6 | provideniya
# Processing Record 26 of Set 6 | kuytun
# Processing Record 27 of Set 6 | nador
# Processing Record 28 of Set 6 | digras
# Processing Record 29 of Set 6 | nishihara
# Processing Record 30 of Set 6 | hay river
# Processing Record 31 of Set 6 | hithadhoo
# Processing Record 32 of Set 6 | staryy oskol
# Processing Record 33 of Set 6 | cherskiy
# Processing Record 34 of Set 6 | marsh harbour
# Processing Record 35 of Set 6 | lavrentiya
# Processing Record 36 of Set 6 | koungheul
# Processing Record 37 of Set 6 | tiksi
# Processing Record 38 of Set 6 | sarkand
# Processing Record 39 of Set 6 | anadyr
# Processing Record 40 of Set 6 | faanui
# Processing Record 41 of Set 6 | jiguani
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | lorengau
# Processing Record 44 of Set 6 | segezha
# Processing Record 45 of Set 6 | lodja
# Processing Record 46 of Set 6 | santa isabel
# Processing Record 47 of Set 6 | zhangye
# Processing Record 48 of Set 6 | yatou
# Processing Record 49 of Set 6 | darnah
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | charters towers
# Processing Record 2 of Set 7 | souillac
# Processing Record 3 of Set 7 | tabas
# Processing Record 4 of Set 7 | novyy urengoy
# Processing Record 5 of Set 7 | cockburn harbour
# City not found. Skipping
# Processing Record 6 of Set 7 | oron
# Processing Record 7 of Set 7 | sawtell
# Processing Record 8 of Set 7 | alvdal
# Processing Record 9 of Set 7 | narsaq
# Processing Record 10 of Set 7 | ola
# Processing Record 11 of Set 7 | clyde river
# Processing Record 12 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 7 | sungairaya
# Processing Record 14 of Set 7 | mudu
# Processing Record 15 of Set 7 | apatou
# Processing Record 16 of Set 7 | rawson
# Processing Record 17 of Set 7 | alofi
# Processing Record 18 of Set 7 | broome
# Processing Record 19 of Set 7 | pokhara
# Processing Record 20 of Set 7 | gat
# Processing Record 21 of Set 7 | trudovoye
# Processing Record 22 of Set 7 | mount isa
# Processing Record 23 of Set 7 | pochutla
# Processing Record 24 of Set 7 | jamestown
# Processing Record 25 of Set 7 | sitka
# Processing Record 26 of Set 7 | shimoda
# Processing Record 27 of Set 7 | victoria
# Processing Record 28 of Set 7 | bani
# Processing Record 29 of Set 7 | gladstone
# Processing Record 30 of Set 7 | kearns
# Processing Record 31 of Set 7 | gorontalo
# Processing Record 32 of Set 7 | nguruka
# Processing Record 33 of Set 7 | san lorenzo de el escorial
# Processing Record 34 of Set 7 | tigil
# Processing Record 35 of Set 7 | padang
# Processing Record 36 of Set 7 | ronda
# Processing Record 37 of Set 7 | neuquen
# Processing Record 38 of Set 7 | aguimes
# Processing Record 39 of Set 7 | acarau
# Processing Record 40 of Set 7 | henderson
# Processing Record 41 of Set 7 | wewak
# Processing Record 42 of Set 7 | sept-iles
# Processing Record 43 of Set 7 | bend
# Processing Record 44 of Set 7 | mayor pablo lagerenza
# Processing Record 45 of Set 7 | pisco
# Processing Record 46 of Set 7 | alexandria
# Processing Record 47 of Set 7 | ust-kamchatsk
# City not found. Skipping
# Processing Record 48 of Set 7 | kiama
# Processing Record 49 of Set 7 | banda aceh
# Processing Record 50 of Set 7 | thompson
# Processing Record 1 of Set 8 | panshi
# Processing Record 2 of Set 8 | shunyi
# Processing Record 3 of Set 8 | laurel
# Processing Record 4 of Set 8 | juifang
# City not found. Skipping
# Processing Record 5 of Set 8 | atar
# Processing Record 6 of Set 8 | morondava
# Processing Record 7 of Set 8 | bredasdorp
# Processing Record 8 of Set 8 | san quintin
# Processing Record 9 of Set 8 | goksun
# Processing Record 10 of Set 8 | poum
# Processing Record 11 of Set 8 | sherlovaya gora
# Processing Record 12 of Set 8 | plast
# Processing Record 13 of Set 8 | roma
# Processing Record 14 of Set 8 | nabari
# Processing Record 15 of Set 8 | umzimvubu
# City not found. Skipping
# Processing Record 16 of Set 8 | alamosa
# Processing Record 17 of Set 8 | montrose
# Processing Record 18 of Set 8 | belaya gora
# Processing Record 19 of Set 8 | buraydah
# Processing Record 20 of Set 8 | kaberamaido
# Processing Record 21 of Set 8 | goderich
# Processing Record 22 of Set 8 | ribeira grande
# Processing Record 23 of Set 8 | sorland
# Processing Record 24 of Set 8 | port-gentil
# Processing Record 25 of Set 8 | viedma
# Processing Record 26 of Set 8 | lieksa
# Processing Record 27 of Set 8 | pula
# Processing Record 28 of Set 8 | san ramon
# Processing Record 29 of Set 8 | mattru
# Processing Record 30 of Set 8 | camacha
# Processing Record 31 of Set 8 | starosubkhangulovo
# Processing Record 32 of Set 8 | bitung
# Processing Record 33 of Set 8 | ponta delgada
# Processing Record 34 of Set 8 | pevek
# Processing Record 35 of Set 8 | ilulissat
# Processing Record 36 of Set 8 | impfondo
# Processing Record 37 of Set 8 | port hedland
# Processing Record 38 of Set 8 | comandau
# Processing Record 39 of Set 8 | lukulu
# Processing Record 40 of Set 8 | palabuhanratu
# City not found. Skipping
# Processing Record 41 of Set 8 | ewa beach
# Processing Record 42 of Set 8 | bambanglipuro
# Processing Record 43 of Set 8 | carmo do paranaiba
# Processing Record 44 of Set 8 | pabrade
# Processing Record 45 of Set 8 | pucara
# Processing Record 46 of Set 8 | praya
# Processing Record 47 of Set 8 | burns lake
# Processing Record 48 of Set 8 | adrar
# Processing Record 49 of Set 8 | milkovo
# Processing Record 50 of Set 8 | duayaw nkwanta
# Processing Record 1 of Set 9 | lagoa
# Processing Record 2 of Set 9 | honningsvag
# Processing Record 3 of Set 9 | bousso
# Processing Record 4 of Set 9 | vila franca do campo
# Processing Record 5 of Set 9 | lively
# Processing Record 6 of Set 9 | port blair
# Processing Record 7 of Set 9 | asau
# Processing Record 8 of Set 9 | placido de castro
# Processing Record 9 of Set 9 | erzin
# Processing Record 10 of Set 9 | huatulco
# Processing Record 11 of Set 9 | heihe
# Processing Record 12 of Set 9 | ullapool
# Processing Record 13 of Set 9 | karia
# Processing Record 14 of Set 9 | dolbeau
# City not found. Skipping
# Processing Record 15 of Set 9 | tuatapere
# Processing Record 16 of Set 9 | bac lieu
# Processing Record 17 of Set 9 | sao filipe
# Processing Record 18 of Set 9 | derzhavinsk
# Processing Record 19 of Set 9 | kassala
# Processing Record 20 of Set 9 | plettenberg bay
# Processing Record 21 of Set 9 | selenginsk
# Processing Record 22 of Set 9 | meaux
# Processing Record 23 of Set 9 | bathsheba
# Processing Record 24 of Set 9 | lashio
# Processing Record 25 of Set 9 | melito di porto salvo
# Processing Record 26 of Set 9 | gamboma
# Processing Record 27 of Set 9 | krasnyy chikoy
# Processing Record 28 of Set 9 | northam
# Processing Record 29 of Set 9 | roznava
# Processing Record 30 of Set 9 | tabou
# Processing Record 31 of Set 9 | saint-philippe
# Processing Record 32 of Set 9 | nantucket
# Processing Record 33 of Set 9 | am timan
# Processing Record 34 of Set 9 | pacific grove
# Processing Record 35 of Set 9 | amahai
# Processing Record 36 of Set 9 | saint anthony
# Processing Record 37 of Set 9 | namibe
# Processing Record 38 of Set 9 | high prairie
# Processing Record 39 of Set 9 | batemans bay
# Processing Record 40 of Set 9 | deputatskiy
# Processing Record 41 of Set 9 | mackenzie
# Processing Record 42 of Set 9 | balimo
# City not found. Skipping
# Processing Record 43 of Set 9 | altamira
# Processing Record 44 of Set 9 | champerico
# Processing Record 45 of Set 9 | abu samrah
# Processing Record 46 of Set 9 | carutapera
# Processing Record 47 of Set 9 | karpogory
# Processing Record 48 of Set 9 | dingle
# Processing Record 49 of Set 9 | yabelo
# Processing Record 50 of Set 9 | franca
# Processing Record 1 of Set 10 | zouxian
# City not found. Skipping
# Processing Record 2 of Set 10 | warrnambool
# Processing Record 3 of Set 10 | bang sao thong
# Processing Record 4 of Set 10 | neyshabur
# Processing Record 5 of Set 10 | gedo
# Processing Record 6 of Set 10 | dali
# Processing Record 7 of Set 10 | sumbawa
# City not found. Skipping
# Processing Record 8 of Set 10 | kalmunai
# Processing Record 9 of Set 10 | lahij
# Processing Record 10 of Set 10 | dunoon
# Processing Record 11 of Set 10 | berlevag
# Processing Record 12 of Set 10 | ponta do sol
# Processing Record 13 of Set 10 | bardiyah
# Processing Record 14 of Set 10 | doha
# Processing Record 15 of Set 10 | balkhash
# Processing Record 16 of Set 10 | purpe
# Processing Record 17 of Set 10 | koygorodok
# Processing Record 18 of Set 10 | yanan
# City not found. Skipping
# Processing Record 19 of Set 10 | riyadh
# Processing Record 20 of Set 10 | narodychi
# Processing Record 21 of Set 10 | alibunan
# Processing Record 22 of Set 10 | louisbourg
# City not found. Skipping
# Processing Record 23 of Set 10 | sembe
# Processing Record 24 of Set 10 | swellendam
# Processing Record 25 of Set 10 | lanzhou
# Processing Record 26 of Set 10 | lamu
# Processing Record 27 of Set 10 | haines junction
# Processing Record 28 of Set 10 | urumqi
# Processing Record 29 of Set 10 | rio grande
# Processing Record 30 of Set 10 | chahal
# Processing Record 31 of Set 10 | chiang kham
# Processing Record 32 of Set 10 | azovo
# Processing Record 33 of Set 10 | tazovskiy
# Processing Record 34 of Set 10 | guerrero negro
# Processing Record 35 of Set 10 | sarkikaraagac
# Processing Record 36 of Set 10 | cody
# Processing Record 37 of Set 10 | tateyama
# Processing Record 38 of Set 10 | lasa
# Processing Record 39 of Set 10 | jalingo
# Processing Record 40 of Set 10 | meulaboh
# Processing Record 41 of Set 10 | dafeng
# Processing Record 42 of Set 10 | amlame
# Processing Record 43 of Set 10 | maracacume
# Processing Record 44 of Set 10 | meyungs
# City not found. Skipping
# Processing Record 45 of Set 10 | mlonggo
# Processing Record 46 of Set 10 | enniscorthy
# Processing Record 47 of Set 10 | billings
# Processing Record 48 of Set 10 | hope
# Processing Record 49 of Set 10 | opuwo
# Processing Record 50 of Set 10 | faxinal
# Processing Record 1 of Set 11 | quang ngai
# Processing Record 2 of Set 11 | havoysund
# Processing Record 3 of Set 11 | whitehorse
# Processing Record 4 of Set 11 | aquidauana
# Processing Record 5 of Set 11 | along
# Processing Record 6 of Set 11 | klaksvik
# Processing Record 7 of Set 11 | tyukalinsk
# Processing Record 8 of Set 11 | wagar
# Processing Record 9 of Set 11 | temizhbekskaya
# Processing Record 10 of Set 11 | ubata
# Processing Record 11 of Set 11 | alyangula
# Processing Record 12 of Set 11 | veraval
# Processing Record 13 of Set 11 | vallenar
# Processing Record 14 of Set 11 | porto novo
# Processing Record 15 of Set 11 | te anau
# Processing Record 16 of Set 11 | kuldiga
# Processing Record 17 of Set 11 | soligalich
# Processing Record 18 of Set 11 | beringovskiy
# Processing Record 19 of Set 11 | raudeberg
# Processing Record 20 of Set 11 | anapskaya
# Processing Record 21 of Set 11 | tarrafal
# Processing Record 22 of Set 11 | barcelos
# Processing Record 23 of Set 11 | bulawayo
# Processing Record 24 of Set 11 | bolshaya dzhalga
# Processing Record 25 of Set 11 | alekseyevka
# Processing Record 26 of Set 11 | markala
# Processing Record 27 of Set 11 | sao joao da barra
# Processing Record 28 of Set 11 | naze
# Processing Record 29 of Set 11 | harrismith
# Processing Record 30 of Set 11 | awjilah
# Processing Record 31 of Set 11 | sal rei
# Processing Record 32 of Set 11 | leningradskiy
# Processing Record 33 of Set 11 | karkaralinsk
# City not found. Skipping
# Processing Record 34 of Set 11 | kattivakkam
# Processing Record 35 of Set 11 | mezen
# Processing Record 36 of Set 11 | banikoara
# Processing Record 37 of Set 11 | odweyne
# Processing Record 38 of Set 11 | rakiv lis
# Processing Record 39 of Set 11 | chemodanovka
# Processing Record 40 of Set 11 | zambezi
# Processing Record 41 of Set 11 | hobyo
# Processing Record 42 of Set 11 | vredendal
# Processing Record 43 of Set 11 | olafsvik
# Processing Record 44 of Set 11 | krasnoselkup
# Processing Record 45 of Set 11 | mosquera
# Processing Record 46 of Set 11 | khonsar
# City not found. Skipping
# Processing Record 47 of Set 11 | muzhi
# Processing Record 48 of Set 11 | samarai
# Processing Record 49 of Set 11 | hwange
# Processing Record 50 of Set 11 | calbuco
# Processing Record 1 of Set 12 | nouadhibou
# Processing Record 2 of Set 12 | kingman
# Processing Record 3 of Set 12 | lata
# Processing Record 4 of Set 12 | disna
# Processing Record 5 of Set 12 | kano
# Processing Record 6 of Set 12 | hami
# Processing Record 7 of Set 12 | gamba
# Processing Record 8 of Set 12 | goure
# Processing Record 9 of Set 12 | dabhol
# Processing Record 10 of Set 12 | odesskoye
# Processing Record 11 of Set 12 | breytovo
# Processing Record 12 of Set 12 | plouzane
# Processing Record 13 of Set 12 | eldikan
# City not found. Skipping
# Processing Record 14 of Set 12 | lompoc
# Processing Record 15 of Set 12 | kumo
# Processing Record 16 of Set 12 | stromness
# Processing Record 17 of Set 12 | devils lake
# Processing Record 18 of Set 12 | ballina
# Processing Record 19 of Set 12 | cali
# Processing Record 20 of Set 12 | egvekinot
# Processing Record 21 of Set 12 | uvira
# Processing Record 22 of Set 12 | wenling
# Processing Record 23 of Set 12 | nkowakowa
# Processing Record 24 of Set 12 | luanda
# Processing Record 25 of Set 12 | grindavik
# Processing Record 26 of Set 12 | rio rancho
# Processing Record 27 of Set 12 | laksham
# Processing Record 28 of Set 12 | bowen
# Processing Record 29 of Set 12 | turukhansk
# Processing Record 30 of Set 12 | sosva
# Processing Record 31 of Set 12 | san rafael
# Processing Record 32 of Set 12 | sakakah
# Processing Record 33 of Set 12 | laguna
# Processing Record 34 of Set 12 | sambava
# Processing Record 35 of Set 12 | japura
# Processing Record 36 of Set 12 | ekibastuz
# Processing Record 37 of Set 12 | nabire
# Processing Record 38 of Set 12 | tommot
# Processing Record 39 of Set 12 | waddan
# Processing Record 40 of Set 12 | gravdal
# Processing Record 41 of Set 12 | nagod
# Processing Record 42 of Set 12 | aksarka
# Processing Record 43 of Set 12 | semikarakorsk
# Processing Record 44 of Set 12 | abha
# Processing Record 45 of Set 12 | pangkalanbuun
# Processing Record 46 of Set 12 | poso
# Processing Record 47 of Set 12 | murashi
# Processing Record 48 of Set 12 | biltine
# Processing Record 49 of Set 12 | omboue
# Processing Record 50 of Set 12 | skagastrond
# City not found. Skipping
# Processing Record 1 of Set 13 | montlucon
# Processing Record 2 of Set 13 | vaitape
# Processing Record 3 of Set 13 | gandai
# Processing Record 4 of Set 13 | lixourion
# Processing Record 5 of Set 13 | port lincoln
# Processing Record 6 of Set 13 | shush
# Processing Record 7 of Set 13 | conceicao da barra
# Processing Record 8 of Set 13 | guiratinga
# Processing Record 9 of Set 13 | mocambique
# City not found. Skipping
# Processing Record 10 of Set 13 | dzhusaly
# City not found. Skipping
# Processing Record 11 of Set 13 | salta
# Processing Record 12 of Set 13 | ondorhaan
# City not found. Skipping
# Processing Record 13 of Set 13 | nyurba
# Processing Record 14 of Set 13 | zlobin
# Processing Record 15 of Set 13 | tocantinopolis
# City not found. Skipping
# Processing Record 16 of Set 13 | barbar
# City not found. Skipping
# Processing Record 17 of Set 13 | ondjiva
# Processing Record 18 of Set 13 | gatesville
# Processing Record 19 of Set 13 | alta floresta
# Processing Record 20 of Set 13 | terre-de-bas
# Processing Record 21 of Set 13 | luba
# Processing Record 22 of Set 13 | atbasar
# Processing Record 23 of Set 13 | kirksville
# Processing Record 24 of Set 13 | hays
# Processing Record 25 of Set 13 | chagda
# City not found. Skipping
# Processing Record 26 of Set 13 | haveli
# Processing Record 27 of Set 13 | kushmurun
# Processing Record 28 of Set 13 | mehamn
# Processing Record 29 of Set 13 | kruisfontein
# Processing Record 30 of Set 13 | zyryanskoye
# Processing Record 31 of Set 13 | airai
# Processing Record 32 of Set 13 | north platte
# Processing Record 33 of Set 13 | pombas
# Processing Record 34 of Set 13 | chester
# Processing Record 35 of Set 13 | waipawa
# Processing Record 36 of Set 13 | itarema
# Processing Record 37 of Set 13 | henties bay
# Processing Record 38 of Set 13 | chumikan
# Processing Record 39 of Set 13 | basoko
# Processing Record 40 of Set 13 | coihaique
# Processing Record 41 of Set 13 | araouane
# Processing Record 42 of Set 13 | saint-georges
# Processing Record 43 of Set 13 | taos
# Processing Record 44 of Set 13 | redlands
# Processing Record 45 of Set 13 | labuhan
# Processing Record 46 of Set 13 | nadym
# Processing Record 47 of Set 13 | nha trang
# Processing Record 48 of Set 13 | luebo
# Processing Record 49 of Set 13 | lhokseumawe
# Processing Record 50 of Set 13 | batagay-alyta
# Processing Record 1 of Set 14 | srikakulam
# Processing Record 2 of Set 14 | yima
# Processing Record 3 of Set 14 | brainerd
# Processing Record 4 of Set 14 | kastamonu
# Processing Record 5 of Set 14 | nalut
# Processing Record 6 of Set 14 | thanh hoa
# Processing Record 7 of Set 14 | arlit
# Processing Record 8 of Set 14 | koungou
# Processing Record 9 of Set 14 | challapata
# Processing Record 10 of Set 14 | tiarei
# Processing Record 11 of Set 14 | tambun
# Processing Record 12 of Set 14 | cambyreta
# City not found. Skipping
# Processing Record 13 of Set 14 | bullhead city
# Processing Record 14 of Set 14 | severnoye
# Processing Record 15 of Set 14 | solwezi
# Processing Record 16 of Set 14 | dodge city
# Processing Record 17 of Set 14 | mayo
# Processing Record 18 of Set 14 | bilibino
# Processing Record 19 of Set 14 | nevers
# Processing Record 20 of Set 14 | tikhvin
# Processing Record 21 of Set 14 | baoshan
# Processing Record 22 of Set 14 | pingdingshan
# Processing Record 23 of Set 14 | yambio
# Processing Record 24 of Set 14 | nokha
# Processing Record 25 of Set 14 | bolobo
# Processing Record 26 of Set 14 | quebo
# Processing Record 27 of Set 14 | hirara
# Processing Record 28 of Set 14 | sur
# Processing Record 29 of Set 14 | yeppoon
# Processing Record 30 of Set 14 | haukipudas
# Processing Record 31 of Set 14 | vrangel
# Processing Record 32 of Set 14 | chegdomyn
# Processing Record 33 of Set 14 | la ronge
# Processing Record 34 of Set 14 | khor
# Processing Record 35 of Set 14 | namangan
# Processing Record 36 of Set 14 | zhigansk
# Processing Record 37 of Set 14 | west plains
# Processing Record 38 of Set 14 | margate
# Processing Record 39 of Set 14 | oak ridge
# Processing Record 40 of Set 14 | kimbe
# Processing Record 41 of Set 14 | saryozek
# Processing Record 42 of Set 14 | agadez
# Processing Record 43 of Set 14 | olinda
# Processing Record 44 of Set 14 | baghdad
# Processing Record 45 of Set 14 | yarmouth
# Processing Record 46 of Set 14 | verkhoshizhemye
# Processing Record 47 of Set 14 | boa vista
# Processing Record 48 of Set 14 | sehithwa
# Processing Record 49 of Set 14 | alipur chatha
# Processing Record 50 of Set 14 | jawhar
# Processing Record 1 of Set 15 | sicuani
# Processing Record 2 of Set 15 | obo
# Processing Record 3 of Set 15 | geresk
# City not found. Skipping
# Processing Record 4 of Set 15 | bajo baudo
# City not found. Skipping
# Processing Record 5 of Set 15 | mogadishu
# Processing Record 6 of Set 15 | pangai
# Processing Record 7 of Set 15 | port macquarie
# Processing Record 8 of Set 15 | ixmiquilpan
# Processing Record 9 of Set 15 | peterhead
# Processing Record 10 of Set 15 | banjar
# Processing Record 11 of Set 15 | la libertad
# Processing Record 12 of Set 15 | kandi
# Processing Record 13 of Set 15 | kaura namoda
# Processing Record 14 of Set 15 | newport
# Processing Record 15 of Set 15 | acapulco
# Processing Record 16 of Set 15 | lubango
# Processing Record 17 of Set 15 | vao
# Processing Record 18 of Set 15 | chihuahua
# Processing Record 19 of Set 15 | necochea
# Processing Record 20 of Set 15 | yulara
# Processing Record 21 of Set 15 | ossora
# Processing Record 22 of Set 15 | yangambi
# Processing Record 23 of Set 15 | ayer itam
# City not found. Skipping
# Processing Record 24 of Set 15 | pointe michel
# Processing Record 25 of Set 15 | baijiantan
# Processing Record 26 of Set 15 | sungai padi
# Processing Record 27 of Set 15 | rubbestadneset
# Processing Record 28 of Set 15 | sayyan
# Processing Record 29 of Set 15 | teya
# Processing Record 30 of Set 15 | chillicothe
# Processing Record 31 of Set 15 | micheweni
# Processing Record 32 of Set 15 | bykov
# Processing Record 33 of Set 15 | sampang
# Processing Record 34 of Set 15 | panalingaan
# Processing Record 35 of Set 15 | kitakata
# Processing Record 36 of Set 15 | mitsamiouli
# Processing Record 37 of Set 15 | thinadhoo
# Processing Record 38 of Set 15 | saku
# Processing Record 39 of Set 15 | bandipur
# Processing Record 40 of Set 15 | marawi
# Processing Record 41 of Set 15 | palmas bellas
# Processing Record 42 of Set 15 | lemesos
# City not found. Skipping
# Processing Record 43 of Set 15 | akhalgori
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0  Chililabombwe      ZM  2022-02-05 19:38:03 -12.3648   27.8229     62.42
# 1        Ushuaia      AR  2022-02-05 19:36:33 -54.8000  -68.3000     64.02
# 2         Murgud      IN  2022-02-05 19:38:03  16.4000   74.2000     63.79
# 3      Mahebourg      MU  2022-02-05 19:38:04 -20.4081   57.7000     80.26
# 4       Kirakira      SB  2022-02-05 19:38:04 -10.4544  161.9205     81.84
# 5           Sibu      MY  2022-02-05 19:38:05   2.3000  111.8167     75.51
# 6       Flinders      AU  2022-02-05 19:38:05 -34.5833  150.8552     69.39
# 7         Atuona      PF  2022-02-05 19:38:05  -9.8000 -139.0333     78.96
# 8          Selma      US  2022-02-05 19:38:06  36.5708 -119.6121     63.03
# 9      Carnarvon      AU  2022-02-05 19:38:06 -24.8667  113.6333     78.87
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        97          93        3.47          light rain
# 1        55          75       24.16          light rain
# 2        78          37        0.85    scattered clouds
# 3        89          75       21.85       broken clouds
# 4        83          97        4.81     overcast clouds
# 5       100          40        1.99    scattered clouds
# 6        83          91        5.99          light rain
# 7        76           6       22.30           clear sky
# 8        52         100        2.10     overcast clouds
# 9        89          75        9.22       broken clouds

# %%
# Create CSV file of DF
csv_weather_file = "WeatherPy_Database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
